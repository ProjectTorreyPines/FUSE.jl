# %% [markdown]
# # Build Notes

# %%
using Revise
using FUSE
using Plots;
FUSE.logging(Logging.Info);

# %% [markdown]
# ## Initialize FPP v1_demount

# %%
ini, act = FUSE.case_parameters(:FPP; version=:v1_demount, init_from=:scalars);

ini.build.layers[:hfs_vacuum_vessel] += ini.build.layers[:hfs_vacuum_vessel_wall_inner] + ini.build.layers[:hfs_vacuum_vessel_wall_outer]
delete!(ini.build.layers,:hfs_vacuum_vessel_wall_inner)
delete!(ini.build.layers,:hfs_vacuum_vessel_wall_outer)
ini.build.layers[:lfs_vacuum_vessel] += ini.build.layers[:lfs_vacuum_vessel_wall_inner] + ini.build.layers[:lfs_vacuum_vessel_wall_outer]
delete!(ini.build.layers,:lfs_vacuum_vessel_wall_inner)
delete!(ini.build.layers,:lfs_vacuum_vessel_wall_outer)
display(ini.build)
ini.equilibrium.B0 = 8.0
display(act.ActorHFSsizing)
act.ActorPFcoilsOpt.update_equilibrium = true
# Out:
# build{Float64}
# ├─ layers ➡ OrderedCollections.OrderedDict{Symbol, Float64}(
# │           :gap_OH => 1.180137712438599
# │           :OH => 0.35554973675585266
# │           :gap_TF_OH => 0.068920461457739
# │           :hfs_TF => 0.3074802716013343
# │           :hfs_gap_low_temp_shield_TF => 0.06892046145773922
# │           :hfs_low_temp_shield => 0.4241901854016936
# │           :hfs_gap_vacuum_vessel_low_temp_shield => 0.06892046145773945
# │           :hfs_vacuum_vessel => 0.17230115364434795
# │           :hfs_gap_high_temp_shield_vacuum_vessel => 0.06892046145773945
# │           :hfs_high_temp_shield => 0.2067613843732179
# │           :hfs_blanket => 0.3316196291966129
# │           :hfs_first_wall => 0.02
# │           :plasma => 3.1014207655982666
# │           :lfs_first_wall => 0.02
# │           :lfs_blanket => 0.7654012311802618
# │           :lfs_high_temp_shield => 0.2067613843732179
# │           :lfs_gap_high_temp_shield_vacuum_vessel => 0.3446023072886959
# │           :lfs_vacuum_vessel => 0.17230115364434795
# │           :lfs_gap_vacuum_vessel_low_temp_shield => 0.068920461457739
# │           :lfs_low_temp_shield => 0.4241901854016943
# │           :lfs_gap_low_temp_shield_TF => 0.17230115364434795
# │           :lfs_TF => 0.3074802716013334
# │           :gap_cryostat => 1.4221989470234107
# │           :cryostat => 0.21209509270084714) [m] Sorted dictionary of layers thicknesses in radial build
# ├─ blanket ➡ missing Fraction of blanket in radial build
# ├─ shield ➡ missing Fraction of shield in radial build
# ├─ vessel ➡ missing Fraction of vessel in radial build
# ├─ plasma_gap ➡ 0.1 Fraction of vacuum gap between first wall and plasma separatrix in radial build
# ├─ symmetric ➡ true Is the build up-down symmetric
# └─ n_first_wall_conformal_layers ➡ 2 Number of layers that are conformal to the first wall
# ActorHFSsizing{Float64}
# ├─ j_tolerance ➡ 0.4 Tolerance on the OH and TF current limits (overrides ActorFluxSwing.j_tolerance)
# ├─ stress_tolerance ➡ 0.2 Tolerance on the OH and TF structural stresses limits
# ├─ aspect_ratio_tolerance ➡ 0.01 Tolerance on the aspect_ratio change
# ├─ do_plot ➡ false Plot
# └─ verbose ➡ false Verbose
# true

# %%
dd = IMAS.dd()
FUSE.init(dd, ini, act; do_plot=false);
FUSE.digest(dd)
# Out:
# GEOMETRY                       EQUILIBRIUM                    TEMPERATURES                   DENSITIES
# ───────────────────────────    ───────────────────────────    ───────────────────────────    ───────────────────────────
# R0 → 4.82 [m]                  B0 → 8 [T]                     Te0 → 22.4 [keV]               ne0 → 2.29e+20 [m⁻³]
# a → 1.38 [m]                   ip → 8 [MA]                    Ti0 → 22.4 [keV]               ne_ped → 1.01e+20 [m⁻³]
# 1/ϵ → 3.5 [m]                  q95 → 8.98                     <Te> → 9.48 [keV]              <ne> → 1.47e+20 [m⁻³]
# κ → 2.29                       βpol → 4.19                    <Ti> → 9.48 [keV]              ne0/<ne> → 1.56
# δ → 0.85                       βtor → 0.0284                  Te0/<Te> → 2.36                fGW → 1.26
# ζ → 0.0514                     βn → 3.91                      Ti0/<Ti> → 2.36                zeff_ped → 2
#                                                                                              <zeff> → 2
#
# PRESSURES                      TRANSPORT                      SOURCES                        CURRENTS
# ───────────────────────────    ───────────────────────────    ───────────────────────────    ───────────────────────────
# P0 → 1.64 [MPa]                τe → 1.17 [s]                  Pec → 65.6 [MW]                ip_bs_aux_ohm → 7.98 [MA]
# <P> → 0.494 [MPa]              τe98 → 0.883 [s]               Pnbi → NaN [MW]                ip_ni → 9.64 [MA]
# P0/<P> → 3.31                  H98y2 → 1.32                   Pic → NaN [MW]                 ip_bs → 8.5 [MA]
#                                ds03 → 0.873                   Plh → NaN [MW]                 ip_aux → 1.13 [MA]
#                                                               Paux_tot → 65.6 [MW]           ip_ohm → -1.65 [MA]
#                                                                                              flattop → NaN [Hours]
#
# BOP                            BUILD                          COSTING
# ───────────────────────────    ───────────────────────────    ───────────────────────────
# Pfusion → 881 [MW]             PF_material → Nb3Sn            levelized_CoE → NaN [$/kWh]
# Qfusion → 13.4                 OH_material → ReBCO            capital_cost → 0 [$B]
# Pelectric_net → NaN [MWe]      TF_material → ReBCO
# Qplant → NaN
# ηthermal_cycle → NaN
#
# ​
# ​
# 24×9 DataFrame
#  Row │ group   details     type      ΔR         R_start   R_end     material      area       volume
#      │ String  String      String    Float64    Float64   Float64   String        Float64    Float64
# ─────┼──────────────────────────────────────────────────────────────────────────────────────────────────
#    1 │ in                            1.19256     0.0       1.19256                15.7396      58.9691
#    2 │ in                  oh        0.359292    1.19256   1.55185  ReBCO          4.742       40.8847
#    3 │ in                            0.0696459   1.55185   1.6215                  0.919199     9.16385
#    4 │ hfs                 tf        0.310717    1.6215    1.93222  ReBCO         10.2687     104.619
#    5 │ hfs                           0.0696459   1.93222   2.00186                 3.86232    137.995
#    6 │ hfs     low temp    shield    0.428655    2.00186   2.43052  Steel         12.8424     384.535
#    7 │ hfs                           0.0696459   2.43052   2.50016                 1.97755     59.3567
#    8 │ hfs     vacuum      vessel    0.174115    2.50016   2.67428  Water          4.81053    144.575
#    9 │ hfs                           0.0696459   2.67428   2.74392                 5.5212     201.233
#   10 │ hfs     high temp   shield    0.208938    2.74392   2.95286  Steel          5.2469     153.849
#   11 │ hfs                 blanket   0.33511     2.95286   3.28797  lithium-lead  17.0572     531.125
#   12 │ hfs     first       wall      0.0202105   3.28797   3.30818  Tungsten       0.427291    11.8152
#   13 │ lhfs                plasma    3.0325      3.30818   6.34068  DT_plasma     17.1917     496.63
#   14 │ lfs     first       wall      0.0202105   6.34068   6.3609   Tungsten       0.427291    11.8152
#   15 │ lfs                 blanket   0.773458    6.3609    7.13435  lithium-lead  17.0572     531.125
#   16 │ lfs     high temp   shield    0.208938    7.13435   7.34329  Steel          5.2469     153.849
#   17 │ lfs                           0.34823     7.34329   7.69152                 5.5212     201.233
#   18 │ lfs     vacuum      vessel    0.174115    7.69152   7.86564  Water          4.81053    144.575
#   19 │ lfs                           0.0696459   7.86564   7.93528                 1.97755     59.3567
#   20 │ lfs     low temp    shield    0.428655    7.93528   8.36394  Steel         12.8424     384.535
#   21 │ lfs                           0.174115    8.36394   8.53805                 3.86232    137.995
#   22 │ lfs                 tf        0.310717    8.53805   8.84877  ReBCO         10.2687     104.619
#   23 │ out                           1.43717     8.84877  10.2859                 58.5848    2491.65
#   24 │ out                 cryostat  0.214328   10.2859   10.5003   Tungsten       5.48604    280.651
# ​
# ​
# ​
# ​
# ​
# ​
# ​

# %%
println("OH R_start = ", dd.build.layer[2].start_radius)
println("OH R_end = ",dd.build.layer[2].end_radius)

println("TF R_start = ", dd.build.layer[4].start_radius)
println("TF R_end = ",dd.build.layer[4].end_radius)

dd.build.layer[8].material = "Steel, Stainless 316"
dd.build.layer[18].material = "Steel, Stainless 316"
dd.build.layer[24].material = "Steel, Stainless 316"


display(dd.build)

display(dd.build.tf)
display(dd.build.oh)
# Out:
# OH R_start = 1.1925602146747947
# OH R_end = 1.5518525802386036
# TF R_start = 1.621498520238003
# TF R_end = 1.9322154262772462
# build
# ├─ layer
# │  ├─ 1
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ 2
# │  │  ├─ identifier ➡ 7653906519645546835
# │  │  ├─ material ➡ "Vacuum"
# │  │  ├─ name ➡ "gap OH"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ 5-element Vector{Float64} [m]
# │  │  │  └─ z ➡ 5-element Vector{Float64} [m]
# │  │  ├─ shape ➡ Function
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 1.19256 [m]
# │  │  ├─ type ➡ 0
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 2
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ 2
# │  │  ├─ identifier ➡ 7141519176361583869
# │  │  ├─ material ➡ "ReBCO"
# │  │  ├─ name ➡ "OH"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ 5-element Vector{Float64} [m]
# │  │  │  └─ z ➡ 5-element Vector{Float64} [m]
# │  │  ├─ shape ➡ Function
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.359292 [m]
# │  │  ├─ type ➡ 1
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 3
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ 2
# │  │  ├─ identifier ➡ 1093819371746655894
# │  │  ├─ material ➡ "Vacuum"
# │  │  ├─ name ➡ "gap TF OH"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ 5-element Vector{Float64} [m]
# │  │  │  └─ z ➡ 5-element Vector{Float64} [m]
# │  │  ├─ shape ➡ Function
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.0696459 [m]
# │  │  ├─ type ➡ 0
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 4
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ 1
# │  │  ├─ identifier ➡ 2182987556743177266
# │  │  ├─ material ➡ "ReBCO"
# │  │  ├─ name ➡ "hfs TF"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ 795-element Vector{Float64} [m]
# │  │  │  └─ z ➡ 795-element Vector{Float64} [m]
# │  │  ├─ shape ➡ 0
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.310717 [m]
# │  │  ├─ type ➡ 2
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 5
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ 1
# │  │  ├─ identifier ➡ 7484895926803519467
# │  │  ├─ material ➡ "Vacuum"
# │  │  ├─ name ➡ "hfs gap low temp shield TF"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ 398-element Vector{Float64} [m]
# │  │  │  └─ z ➡ 398-element Vector{Float64} [m]
# │  │  ├─ shape ➡ 7
# │  │  ├─ shape_parameters ➡ [8.56206,12.5768]
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.0696459 [m]
# │  │  ├─ type ➡ 0
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 6
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ 1
# │  │  ├─ identifier ➡ -5851185619594387977
# │  │  ├─ material ➡ "Steel, Stainless 316"
# │  │  ├─ name ➡ "hfs low temp shield"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ 398-element Vector{Float64} [m]
# │  │  │  └─ z ➡ 398-element Vector{Float64} [m]
# │  │  ├─ shape ➡ 1
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.428655 [m]
# │  │  ├─ type ➡ 3
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 7
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ 1
# │  │  ├─ identifier ➡ -5412198221477894699
# │  │  ├─ material ➡ "Vacuum"
# │  │  ├─ name ➡ "hfs gap vacuum vessel low temp shield"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ 398-element Vector{Float64} [m]
# │  │  │  └─ z ➡ 398-element Vector{Float64} [m]
# │  │  ├─ shape ➡ 1
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.0696459 [m]
# │  │  ├─ type ➡ 0
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 8
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ 1
# │  │  ├─ identifier ➡ 1206243572240661300
# │  │  ├─ material ➡ "Steel, Stainless 316"
# │  │  ├─ name ➡ "hfs vacuum vessel"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ 398-element Vector{Float64} [m]
# │  │  │  └─ z ➡ 398-element Vector{Float64} [m]
# │  │  ├─ shape ➡ 1
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.174115 [m]
# │  │  ├─ type ➡ 6
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 9
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ 1
# │  │  ├─ identifier ➡ -7165473358819180756
# │  │  ├─ material ➡ "Vacuum"
# │  │  ├─ name ➡ "hfs gap high temp shield vacuum vessel"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ 398-element Vector{Float64} [m]
# │  │  │  └─ z ➡ 398-element Vector{Float64} [m]
# │  │  ├─ shape ➡ 1
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.0696459 [m]
# │  │  ├─ type ➡ 0
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 10
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ 1
# │  │  ├─ identifier ➡ -9181192021684971691
# │  │  ├─ material ➡ "Steel, Stainless 316"
# │  │  ├─ name ➡ "hfs high temp shield"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ 398-element Vector{Float64} [m]
# │  │  │  └─ z ➡ 398-element Vector{Float64} [m]
# │  │  ├─ shape ➡ 1
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.208938 [m]
# │  │  ├─ type ➡ 3
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 11
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ 1
# │  │  ├─ identifier ➡ -934060281195744350
# │  │  ├─ material ➡ "lithium-lead"
# │  │  ├─ name ➡ "hfs blanket"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ 398-element Vector{Float64} [m]
# │  │  │  └─ z ➡ 398-element Vector{Float64} [m]
# │  │  ├─ shape ➡ 1
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.33511 [m]
# │  │  ├─ type ➡ 4
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 12
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ 1
# │  │  ├─ identifier ➡ 8020416500513164811
# │  │  ├─ material ➡ "Tungsten"
# │  │  ├─ name ➡ "hfs first wall"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ 439-element Vector{Float64} [m]
# │  │  │  └─ z ➡ 439-element Vector{Float64} [m]
# │  │  ├─ shape ➡ 0
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.0202105 [m]
# │  │  ├─ type ➡ 5
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 13
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ 0
# │  │  ├─ identifier ➡ -8279580463188355954
# │  │  ├─ material ➡ "DT_plasma"
# │  │  ├─ name ➡ "plasma"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ 213-element Vector{Float64} [m]
# │  │  │  └─ z ➡ 213-element Vector{Float64} [m]
# │  │  ├─ shape ➡ 2
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 3.0325 [m]
# │  │  ├─ type ➡ -1
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 14
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ -1
# │  │  ├─ identifier ➡ 8020416500513164811
# │  │  ├─ material ➡ "Tungsten"
# │  │  ├─ name ➡ "lfs first wall"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ Function [m]
# │  │  │  └─ z ➡ Function [m]
# │  │  ├─ shape ➡ Function
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.0202105 [m]
# │  │  ├─ type ➡ 5
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 15
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ -1
# │  │  ├─ identifier ➡ -934060281195744350
# │  │  ├─ material ➡ "lithium-lead"
# │  │  ├─ name ➡ "lfs blanket"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ Function [m]
# │  │  │  └─ z ➡ Function [m]
# │  │  ├─ shape ➡ Function
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.773458 [m]
# │  │  ├─ type ➡ 4
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 16
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ -1
# │  │  ├─ identifier ➡ -9181192021684971691
# │  │  ├─ material ➡ "Steel, Stainless 316"
# │  │  ├─ name ➡ "lfs high temp shield"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ Function [m]
# │  │  │  └─ z ➡ Function [m]
# │  │  ├─ shape ➡ Function
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.208938 [m]
# │  │  ├─ type ➡ 3
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 17
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ -1
# │  │  ├─ identifier ➡ -7165473358819180756
# │  │  ├─ material ➡ "Vacuum"
# │  │  ├─ name ➡ "lfs gap high temp shield vacuum vessel"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ Function [m]
# │  │  │  └─ z ➡ Function [m]
# │  │  ├─ shape ➡ Function
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.34823 [m]
# │  │  ├─ type ➡ 0
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 18
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ -1
# │  │  ├─ identifier ➡ 1206243572240661300
# │  │  ├─ material ➡ "Steel, Stainless 316"
# │  │  ├─ name ➡ "lfs vacuum vessel"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ Function [m]
# │  │  │  └─ z ➡ Function [m]
# │  │  ├─ shape ➡ Function
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.174115 [m]
# │  │  ├─ type ➡ 6
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 19
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ -1
# │  │  ├─ identifier ➡ -5412198221477894699
# │  │  ├─ material ➡ "Vacuum"
# │  │  ├─ name ➡ "lfs gap vacuum vessel low temp shield"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ Function [m]
# │  │  │  └─ z ➡ Function [m]
# │  │  ├─ shape ➡ Function
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.0696459 [m]
# │  │  ├─ type ➡ 0
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 20
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ -1
# │  │  ├─ identifier ➡ -5851185619594387977
# │  │  ├─ material ➡ "Steel, Stainless 316"
# │  │  ├─ name ➡ "lfs low temp shield"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ Function [m]
# │  │  │  └─ z ➡ Function [m]
# │  │  ├─ shape ➡ Function
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.428655 [m]
# │  │  ├─ type ➡ 3
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 21
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ -1
# │  │  ├─ identifier ➡ 7484895926803519467
# │  │  ├─ material ➡ "Vacuum"
# │  │  ├─ name ➡ "lfs gap low temp shield TF"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ Function [m]
# │  │  │  └─ z ➡ Function [m]
# │  │  ├─ shape ➡ Function
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.174115 [m]
# │  │  ├─ type ➡ 0
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 22
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ -1
# │  │  ├─ identifier ➡ 2182987556743177266
# │  │  ├─ material ➡ "ReBCO"
# │  │  ├─ name ➡ "lfs TF"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ Function [m]
# │  │  │  └─ z ➡ Function [m]
# │  │  ├─ shape ➡ Function
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 0.310717 [m]
# │  │  ├─ type ➡ 2
# │  │  └─ volume ➡ Function [m^3]
# │  ├─ 23
# │  │  ├─ area ➡ Function [m^2]
# │  │  ├─ end_radius ➡ Function [m]
# │  │  ├─ fs ➡ 3
# │  │  ├─ identifier ➡ 8131172228931093600
# │  │  ├─ material ➡ "Vacuum"
# │  │  ├─ name ➡ "gap cryostat"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ 103-element Vector{Float64} [m]
# │  │  │  └─ z ➡ 103-element Vector{Float64} [m]
# │  │  ├─ shape ➡ 1
# │  │  ├─ shape_parameters ➡ Function
# │  │  ├─ start_radius ➡ Function [m]
# │  │  ├─ thickness ➡ 1.43717 [m]
# │  │  ├─ type ➡ 0
# │  │  └─ volume ➡ Function [m^3]
# │  └─ 24
# │     ├─ area ➡ Function [m^2]
# │     ├─ end_radius ➡ Function [m]
# │     ├─ fs ➡ 3
# │     ├─ identifier ➡ 8103449356622470855
# │     ├─ material ➡ "Tungsten"
# │     ├─ name ➡ "cryostat"
# │     ├─ outline
# │     │  ├─ r ➡ 103-element Vector{Float64} [m]
# │     │  └─ z ➡ 103-element Vector{Float64} [m]
# │     ├─ shape ➡ 112
# │     ├─ shape_parameters ➡ [16.311,13.3858,0.0164886]
# │     ├─ start_radius ➡ Function [m]
# │     ├─ thickness ➡ 0.214328 [m]
# │     ├─ type ➡ 7
# │     └─ volume ➡ Function [m^3]
# ├─ oh
# │  └─ technology
# │     ├─ JxB_strain ➡ 0
# │     ├─ fraction_stainless ➡ 0.5
# │     ├─ fraction_void ➡ 0.1
# │     ├─ material ➡ "ReBCO"
# │     ├─ ratio_SC_to_copper ➡ 1
# │     ├─ temperature ➡ 20 [K]
# │     └─ thermal_strain ➡ 0
# ├─ pf_active
# │  ├─ rail
# │  │  ├─ 1
# │  │  │  ├─ coils_cleareance ➡ 0.0449115 [m]
# │  │  │  ├─ coils_elements_area ➡ 0.0025 [m^2]
# │  │  │  ├─ coils_number ➡ 6
# │  │  │  ├─ name ➡ "OH"
# │  │  │  └─ outline
# │  │  │     ├─ distance ➡ 6-element Vector{Float64} [m]
# │  │  │     ├─ r ➡ 6-element Vector{Float64} [m]
# │  │  │     └─ z ➡ 6-element Vector{Float64} [m]
# │  │  └─ 2
# │  │     ├─ coils_cleareance ➡ 0.0449115 [m]
# │  │     ├─ coils_elements_area ➡ 0.0025 [m^2]
# │  │     ├─ coils_number ➡ 5
# │  │     ├─ name ➡ "gap cryostat"
# │  │     └─ outline
# │  │        ├─ distance ➡ 1635-element Vector{Float64} [m]
# │  │        ├─ r ➡ 1635-element Vector{Float64} [m]
# │  │        └─ z ➡ 1635-element Vector{Float64} [m]
# │  └─ technology
# │     ├─ JxB_strain ➡ 0
# │     ├─ fraction_stainless ➡ 0.5
# │     ├─ fraction_void ➡ 0.1
# │     ├─ material ➡ "Nb3Sn"
# │     ├─ ratio_SC_to_copper ➡ 1
# │     ├─ temperature ➡ 4.2 [K]
# │     └─ thermal_strain ➡ 0
# ├─ structure
# │  ├─ 1
# │  │  ├─ material ➡ "Tungsten"
# │  │  ├─ name ➡ "Upper divertor"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ 177-element Vector{Float64} [m]
# │  │  │  └─ z ➡ 177-element Vector{Float64} [m]
# │  │  ├─ toroidal_extent ➡ 6.28319 [rad]
# │  │  └─ type ➡ 8
# │  ├─ 2
# │  │  ├─ material ➡ "Tungsten"
# │  │  ├─ name ➡ "Lower divertor"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ 177-element Vector{Float64} [m]
# │  │  │  └─ z ➡ 177-element Vector{Float64} [m]
# │  │  ├─ toroidal_extent ➡ 6.28319 [rad]
# │  │  └─ type ➡ 8
# │  ├─ 3
# │  │  ├─ name ➡ "LFS blanket"
# │  │  ├─ outline
# │  │  │  ├─ r ➡ 294-element Vector{Float64} [m]
# │  │  │  └─ z ➡ 294-element Vector{Float64} [m]
# │  │  ├─ toroidal_extent ➡ 6.28319 [rad]
# │  │  └─ type ➡ 4
# │  └─ 4
# │     ├─ name ➡ "HFS blanket"
# │     ├─ outline
# │     │  ├─ r ➡ 111-element Vector{Float64} [m]
# │     │  └─ z ➡ 111-element Vector{Float64} [m]
# │     ├─ toroidal_extent ➡ 6.28319 [rad]
# │     └─ type ➡ 4
# └─ tf
#    ├─ coils_n ➡ 16
#    ├─ ripple ➡ 0.01
#    ├─ technology
#    │  ├─ JxB_strain ➡ 0
#    │  ├─ fraction_stainless ➡ 0.5
#    │  ├─ fraction_void ➡ 0.1
#    │  ├─ material ➡ "ReBCO"
#    │  ├─ ratio_SC_to_copper ➡ 1
#    │  ├─ temperature ➡ 20 [K]
#    │  └─ thermal_strain ➡ 0
#    └─ wedge_thickness ➡ 0.636761 [m]
# tf
# ├─ coils_n ➡ 16
# ├─ ripple ➡ 0.01
# ├─ technology
# │  ├─ JxB_strain ➡ 0
# │  ├─ fraction_stainless ➡ 0.5
# │  ├─ fraction_void ➡ 0.1
# │  ├─ material ➡ "ReBCO"
# │  ├─ ratio_SC_to_copper ➡ 1
# │  ├─ temperature ➡ 20 [K]
# │  └─ thermal_strain ➡ 0
# └─ wedge_thickness ➡ 0.636761 [m]
# oh
# └─ technology
#    ├─ JxB_strain ➡ 0
#    ├─ fraction_stainless ➡ 0.5
#    ├─ fraction_void ➡ 0.1
#    ├─ material ➡ "ReBCO"
#    ├─ ratio_SC_to_copper ➡ 1
#    ├─ temperature ➡ 20 [K]
#    └─ thermal_strain ➡ 0

# %% [markdown]
# ## Experiment with HFS build settings

# %%
act.ActorHFSsizing.do_plot = true
act.ActorHFSsizing.verbose = true
act.ActorHFSsizing.aspect_ratio_tolerance = 0.01
act.ActorHFSsizing.j_tolerance = 0.5
act.ActorHFSsizing.stress_tolerance = 0.2
act.ActorHFSsizing.operate_at_j_crit = true
act.ActorHFSsizing
# Out:
# act.ActorHFSsizing.operate_at_j_crit does not exist
#
# Stacktrace:
#  [1] setproperty!(parameters::FUSE.FUSEparameters__ActorHFSsizing{Float64}, field::Symbol, value::Bool)
#    @ SimulationParameters ~/.julia/dev/SimulationParameters/src/parameters.jl:87
#  [2] top-level scope
#    @ In[31]:6

# %%
FUSE.ActorHFSsizing(dd, act);
# Out:
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     3.271553e-01
#
#  * Found with
#     Algorithm:     Nelder-Mead
#
#  * Convergence measures
#     √(Σ(yᵢ-ȳ)²)/n ≤ 1.0e-08
#
#  * Work counters
#     Seconds run:   1  (vs limit Inf)
#     Iterations:    201
#     f(x) calls:    375
# [OH.thickness, dd.build.oh.technology.fraction_stainless] = [1.4009777225503441, 0.614610493742062]
# [TFhfs.thickness, dd.build.tf.technology.fraction_stainless] = [0.8490140802897415, 0.772398887876105]
#
# target_B0 = 8.0
# (dd.build.tf.max_b_field * TFhfs.end_radius) / R0_of_B0 = 8.0
#
# dd.build.oh.flattop_duration = 180403.70018831527
#
# dd.build.oh.max_j = 1.3970467630299147e7
# dd.build.oh.critical_j = 2.095209707694067e7
#
# dd.build.tf.max_j = 2.2309630994656358e7
# dd.build.tf.critical_j = 3.465361052972569e7
#
# maximum(dd.solid_mechanics.center_stack.stress.vonmises.oh) = 6.662919639637326e8
# stainless_steel.yield_strength = 8.0e8
#
# maximum(dd.solid_mechanics.center_stack.stress.vonmises.tf) = 6.95814896343382e8
# stainless_steel.yield_strength = 8.0e8
#
# ϵ = 3.9391887865669863
# old_ϵ = 3.4526818984452188
# AssertionError: Plasma aspect ratio changed more than 0.01 (3.4526818984452188 --> 3.9391887865669863)
#
# Stacktrace:
#  [1] _step(actor::FUSE.ActorHFSsizing)
#    @ FUSE ~/.julia/dev/FUSE/src/actors/build/hfs_actor.jl:226
#  [2] macro expansion
#    @ ~/.julia/dev/FUSE/src/actors/abstract_actors.jl:37 [inlined]
#  [3] macro expansion
#    @ ~/.julia/packages/TimerOutputs/LHjFw/src/TimerOutput.jl:237 [inlined]
#  [4] step(::FUSE.ActorHFSsizing; kw::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#    @ FUSE ~/.julia/dev/FUSE/src/actors/abstract_actors.jl:34
#  [5] step
#    @ ~/.julia/dev/FUSE/src/actors/abstract_actors.jl:29 [inlined]
#  [6] FUSE.ActorHFSsizing(dd::IMASDD.dd{Float64}, act::FUSE.ParametersActors{Float64}; kw::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#    @ FUSE ~/.julia/dev/FUSE/src/actors/build/hfs_actor.jl:37
#  [7] FUSE.ActorHFSsizing(dd::IMASDD.dd{Float64}, act::FUSE.ParametersActors{Float64})
#    @ FUSE ~/.julia/dev/FUSE/src/actors/build/hfs_actor.jl:31
#  [8] top-level scope
#    @ In[32]:1

# %%
FUSE.ActorLFSsizing(dd, act);
FUSE.ActorCXbuild(dd, act);
FUSE.ActorPFcoilsOpt(dd, act);
FUSE.ActorPassiveStructures(dd,act);
# Out:
# ┌ Warning: weight_strike>0 but no strike point found
# └ @ FUSE ~/.julia/dev/FUSE/src/actors/pf/pf_active_actor.jl:550

# %%
using Printf

@printf("OH R_start = %.2f m\n", dd.build.layer[2].start_radius)
@printf("OH R_end   = %.2f m\n",dd.build.layer[2].end_radius)

@printf("TF R_start = %.2f m\n", dd.build.layer[4].start_radius)
@printf("TF R_end   = %.2f m\n",dd.build.layer[4].end_radius)

#display(dd.build.tf)
#display(dd.build.oh)

tf_j_max = dd.build.tf.max_j
oh_j_max = dd.build.oh.max_j

tf_j_crit = dd.build.tf.critical_j
oh_j_crit = dd.build.oh.critical_j

tf_vms_max = (maximum(abs.(dd.solid_mechanics.center_stack.stress.vonmises.tf)))
oh_vms_max = (maximum(abs.(dd.solid_mechanics.center_stack.stress.vonmises.oh)))


@printf("\n")
@printf("TF stainless_fraction = %.3f\n", dd.build.tf.technology.fraction_stainless)
@printf("OH stainless_fraction = %.3f\n", dd.build.oh.technology.fraction_stainless)

@printf("\n")
@printf("TF J_op = %.1f MA\n", tf_j_max/1e6)
#@printf("TF J_max = %.1f MA\n", tf_j_crit*(1-act.ActorHFSsizing.j_tolerance)/1e6)
@printf("TF J_crit = %.1f MA\n", tf_j_crit/1e6)

@printf("\n")
@printf("OH J_op = %.1f MA\n", oh_j_max/1e6)
#@printf("OH J_max = %.1f MA\n", oh_j_crit*(1-act.ActorHFSsizing.j_tolerance)/1e6)
@printf("OH J_crit = %.1f MA\n", oh_j_crit/1e6)

@printf("\n")
@printf("TF stress_op = %.1f MPa\n", tf_vms_max/1e6)
#@printf("TF stress_max = %.1f MPa\n", 800*(1-act.ActorHFSsizing.stress_tolerance))
@printf("TF stress_crit = %.1f MPa\n", 800)

@printf("\n")
@printf("OH stress_op = %.1f MPa\n", oh_vms_max/1e6)
#@printf("OH stress_max = %.1f MPa\n", 800*(1-act.ActorHFSsizing.stress_tolerance))
@printf("OH stress_crit = %.1f MPa\n", 800)
# Out:
# OH R_start = 0.35 m
# OH R_end   = 1.75 m
# TF R_start = 1.82 m
# TF R_end   = 2.67 m
#
# TF stainless_fraction = 0.772
# OH stainless_fraction = 0.615
#
# TF J_op = 22.3 MA
# TF J_crit = 34.7 MA
#
# OH J_op = 14.0 MA
# OH J_crit = 21.0 MA
#
# TF stress_op = 695.8 MPa
# TF stress_crit = 800.0 MPa
#
# OH stress_op = 666.3 MPa
# OH stress_crit = 800.0 MPa

# %%
plot(dd.solid_mechanics.center_stack.stress)

# %% [markdown]
# ## Change CX build settings

# %%
FUSE.digest(dd)
# Out:
# GEOMETRY                       EQUILIBRIUM                    TEMPERATURES                   DENSITIES
# ───────────────────────────    ───────────────────────────    ───────────────────────────    ───────────────────────────
# R0 → 4.82 [m]                  B0 → 8 [T]                     Te0 → 22.4 [keV]               ne0 → 2.29e+20 [m⁻³]
# a → 1.37 [m]                   ip → 7.88 [MA]                 Ti0 → 22.4 [keV]               ne_ped → 1.01e+20 [m⁻³]
# 1/ϵ → 3.51 [m]                 q95 → 8.73                     <Te> → 9.48 [keV]              <ne> → 1.47e+20 [m⁻³]
# κ → 2.2                        βpol → 4.19                    <Ti> → 9.48 [keV]              ne0/<ne> → 1.56
# δ → 0.898                      βtor → 0.0284                  Te0/<Te> → 2.36                fGW → 1.27
# ζ → 0.104                      βn → 3.97                      Ti0/<Ti> → 2.36                zeff_ped → 2
#                                                                                              <zeff> → 2
#
# PRESSURES                      TRANSPORT                      SOURCES                        CURRENTS
# ───────────────────────────    ───────────────────────────    ───────────────────────────    ───────────────────────────
# P0 → 1.64 [MPa]                τe → 1.17 [s]                  Pec → 65.6 [MW]                ip_bs_aux_ohm → 7.98 [MA]
# <P> → 0.494 [MPa]              τe98 → 0.844 [s]               Pnbi → NaN [MW]                ip_ni → 9.63 [MA]
# P0/<P> → 3.31                  H98y2 → 1.38                   Pic → NaN [MW]                 ip_bs → 8.5 [MA]
#                                ds03 → 0.911                   Plh → NaN [MW]                 ip_aux → 1.13 [MA]
#                                                               Paux_tot → 65.6 [MW]           ip_ohm → -1.65 [MA]
#                                                                                              flattop → 50.1 [Hours]
#
# BOP                            BUILD                          COSTING
# ───────────────────────────    ───────────────────────────    ───────────────────────────
# Pfusion → 881 [MW]             PF_material → Nb3Sn            levelized_CoE → NaN [$/kWh]
# Qfusion → 13.4                 OH_material → ReBCO            capital_cost → 0 [$B]
# Pelectric_net → NaN [MWe]      TF_material → ReBCO
# Qplant → NaN
# ηthermal_cycle → NaN
#
# ​
# ​
# 24×9 DataFrame
#  Row │ group   details     type      ΔR         R_start    R_end      material      area       volume
#      │ String  String      String    Float64    Float64    Float64    String        Float64    Float64
# ─────┼────────────────────────────────────────────────────────────────────────────────────────────────────
#    1 │ in                            0.350244    0.0        0.350244                 5.00784      5.51026
#    2 │ in                  oh        1.40098     0.350244   1.75122   ReBCO         20.0314     132.246
#    3 │ in                            0.0696459   1.75122    1.82087                  0.995807    11.175
#    4 │ hfs                 tf        0.849014    1.82087    2.66988   ReBCO         29.6403     301.981
#    5 │ hfs                           0.0696459   2.66988    2.73953                  4.66499    198.737
#    6 │ hfs     low temp    shield    0.428655    2.73953    3.16818   Steel         12.8491     453.301
#    7 │ hfs                           0.0696459   3.16818    3.23783                  2.25905     83.0389
#    8 │ hfs     vacuum      vessel    0.174115    3.23783    3.41194   Steel          4.80235    169.557
#    9 │ hfs                           0.0696459   3.41194    3.48159                  6.78427    287.104
#   10 │ hfs     high temp   shield    0.208938    3.48159    3.69053   Steel          5.17171    177.127
#   11 │ hfs                 blanket   0.33511     3.69053    4.02564   lithium-lead  16.9138     610.984
#   12 │ hfs     first       wall      0.0202105   4.02564    4.04585   Tungsten       0.427291    13.7956
#   13 │ lhfs                plasma    3.0325      4.04585    7.07835   DT_plasma     17.1917     576.312
#   14 │ lfs     first       wall      0.0202105   7.07835    7.09856   Tungsten       0.427291    13.7956
#   15 │ lfs                 blanket   0.773458    7.09856    7.87202   lithium-lead  16.9138     610.984
#   16 │ lfs     high temp   shield    0.208938    7.87202    8.08096   Steel          5.17171    177.127
#   17 │ lfs                           0.44781     8.08096    8.52877                  6.78427    287.104
#   18 │ lfs     vacuum      vessel    0.174115    8.52877    8.70288   Steel          4.80235    169.557
#   19 │ lfs                           0.089562    8.70288    8.79245                  2.25905     83.0389
#   20 │ lfs     low temp    shield    0.428655    8.79245    9.2211    Steel         12.8491     453.301
#   21 │ lfs                           0.223905    9.2211     9.44501                  4.66499    198.737
#   22 │ lfs                 tf        0.849014    9.44501   10.294     ReBCO         29.6403     301.981
#   23 │ out                           1.43717    10.294     11.7312                  66.0592    3191.78
#   24 │ out                 cryostat  0.214328   11.7312    11.9455    Tungsten       5.99617    346.476
# ​
# ​
# ​
# ​
# ​
# ​
# ​
# ​
