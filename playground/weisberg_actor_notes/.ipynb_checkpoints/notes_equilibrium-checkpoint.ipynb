# %% [markdown]
# # Equilibirum notes

# %%
using Revise
using FUSE
using Plots;
FUSE.logging(Logging.Info);
# Out:
# WARNING: redefinition of constant UNIT_FORMATS. This may fail, cause incorrect answers, or produce other errors.

# %% [markdown]
# ### Comparing Solovev equilibirum with CHEASE equilibrium to the original ITER ods equilibrium

# %%
### Solovev init equilibrium
dd, ini, act = FUSE.init(:ITER, init_from=:ods);
eq_plot = plot(dd.equilibrium, label="ITER ods equilibrium", coordinate=:psi)

### CHEASE equilibrium
act.ActorEquilibrium.model = :CHEASE
act.ActorCHEASE.free_boundary = false
FUSE.ActorEquilibrium(dd, act)
display(plot!(eq_plot, dd.equilibrium, label="CHEASE equilibrium", coordinate=:psi)
#FUSE.ActorEquilibrium(dd,act)
#display(plot!(eq_plot,dd.equilibrium, label="CHEASE equilibrium 3"))
#FUSE.ActorEquilibrium(dd,act)
#display(plot!(eq_plot,dd.equilibrium, label="CHEASE equilibrium 4"))

# %% [markdown]
# ### Finding a MXH parametrization of the boundary for ITER

# %%
import MillerExtendedHarmonic: flat_coeffs
dd, ini, act = FUSE.init(:ITER, init_from=:ods);
eqt = dd.equilibrium.time_slice[]
eqt_bound = eqt.boundary.outline
psi_close = (eqt.profiles_1d.psi[end-1] + 5 * eqt.profiles_1d.psi[end]) / 6
r_bound, z_bound = IMAS.flux_surface(eqt, psi_close)

eq_plot = plot(r_bound, z_bound, label="0.99 of original boundary shape")
for order in [6]
    mxh = IMAS.MXH(r_bound, z_bound, order)
    @show round.(flat_coeffs(mxh), digits=5)
    plot!(mxh, label="MXH $order")
end
display(plot!(eqt_bound.r, eqt_bound.z, label="original boundary shape", color="black", marker="x", lw=0, markersize=1))

# %% [markdown]
# ### Comparing CHEASE deadstart from MXH parametrization vs. Miller parametrization

# %%
dd, ini, act = FUSE.init(:ITER, init_from=:ods);
eq_plot = plot(dd.equilibrium, label="ITER ODS eq")
display(eq_plot)

# CHEASE deadstart MXH
dd = IMAS.dd()
ini, act = FUSE.case_parameters(:ITER, init_from=:scalars);
ini.equilibrium.boundary_from = :MXH_params
act.ActorEquilibrium.model = :CHEASE
dd = FUSE.init(dd, ini, act)
plot!(eq_plot, dd.equilibrium, label="CHEASE deadstart MXH")

# CHEASE deadstart MILLER
dd = IMAS.dd()
ini, act = FUSE.case_parameters(:ITER, init_from=:scalars);
ini.equilibrium.boundary_from = :scalars
act.ActorEquilibrium.model = :CHEASE
act.ActorCHEASE.free_boundary = false
dd = FUSE.init(dd, ini, act)
display(plot!(eq_plot, dd.equilibrium, label="CHEASE deadstart Miller"))
# Out:
# Parameter ini.equilibrium.R0 [m] is not set
#
# Stacktrace:
#  [1] getproperty(parameters::FUSE.FUSEparameters__equilibrium{Float64}, field::Symbol)
#    @ SimulationParameters ~/.julia/dev/SimulationParameters/src/parameters.jl:41
#  [2] macro expansion
#    @ ~/.julia/dev/FUSE/src/ddinit/init_equilibrium.jl:89 [inlined]
#  [3] macro expansion
#    @ ~/.julia/packages/TimerOutputs/LHjFw/src/TimerOutput.jl:237 [inlined]
#  [4] init_equilibrium(dd::IMASDD.dd{Float64}, ini::FUSE.ParametersInits{Float64}, act::FUSE.ParametersActors{Float64})
#    @ FUSE ~/.julia/dev/FUSE/src/ddinit/init_equilibrium.jl:11
#  [5] macro expansion
#    @ ~/.julia/dev/FUSE/src/ddinit/init.jl:21 [inlined]
#  [6] macro expansion
#    @ ~/.julia/packages/TimerOutputs/LHjFw/src/TimerOutput.jl:237 [inlined]
#  [7] init(dd::IMASDD.dd{Float64}, ini::FUSE.ParametersInits{Float64}, act::FUSE.ParametersActors{Float64}; do_plot::Bool)
#    @ FUSE ~/.julia/dev/FUSE/src/ddinit/init.jl:12
#  [8] init(dd::IMASDD.dd{Float64}, ini::FUSE.ParametersInits{Float64}, act::FUSE.ParametersActors{Float64})
#    @ FUSE ~/.julia/dev/FUSE/src/ddinit/init.jl:10
#  [9] top-level scope
#    @ In[4]:19
