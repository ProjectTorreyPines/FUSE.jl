# %% [markdown]
# # Blanket

# %%
using Revise
using FUSE
using Plots;
FUSE.logging(Logging.Info);

# %% [markdown]
# ### Initialize case

# %%
ini, act = FUSE.case_parameters(:FPP; version=:v1_demount, init_from=:scalars);
dd = FUSE.init(ini, act; do_plot=false);

# %% [markdown]
# ### Run Neutronics actors

# %%
FUSE.ActorNeutronics(dd, act; do_plot=true);

# %% [markdown]
# ### Running the blanket actor
# [ActorBlanket documentation](https://fuse.help/actors.html#Blanket)

# %%
dd.build.structure
act.ActorBlanket.minimum_first_wall_thickness = 0.02
FUSE.ActorBlanket(dd, act, verbose=true);
dd.blanket
# Out:
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     6.551939e-02
#
#  * Found with
#     Algorithm:     Nelder-Mead
#
#  * Convergence measures
#     √(Σ(yᵢ-ȳ)²)/n ≤ 1.0e-08
#
#  * Work counters
#     Seconds run:   2  (vs limit Inf)
#     Iterations:    355
#     f(x) calls:    659
# blanket
# ├─ module
# │  ├─ 1
# │  │  ├─ layer
# │  │  │  ├─ 1
# │  │  │  │  ├─ material ➡ "Steel, Stainless 316"
# │  │  │  │  ├─ midplane_thickness ➡ 0.0206222 [m]
# │  │  │  │  └─ name ➡ "lfs first wall"
# │  │  │  ├─ 2
# │  │  │  │  ├─ material ➡ "lithium-lead: Li6/7=29.927"
# │  │  │  │  ├─ midplane_thickness ➡ 0.773458 [m]
# │  │  │  │  └─ name ➡ "lfs blanket"
# │  │  │  └─ 3
# │  │  │     ├─ material ➡ "Tungsten"
# │  │  │     ├─ midplane_thickness ➡ 0.17443 [m]
# │  │  │     └─ name ➡ "lfs high temp shield"
# │  │  ├─ name ➡ "LFS blanket"
# │  │  └─ time_slice
# │  │     └─ 1
# │  │        ├─ neutron_shine_through ➡ 0.245124
# │  │        ├─ power_incident_neutrons ➡ 4.08268e+08 [W]
# │  │        ├─ power_incident_radiated ➡ 0 [W]
# │  │        ├─ power_thermal_extracted ➡ 4.89922e+08 [W]
# │  │        ├─ power_thermal_neutrons ➡ 4.89922e+08 [W]
# │  │        ├─ power_thermal_radiated ➡ 0 [W]
# │  │        └─ tritium_breeding_ratio ➡ 1.4015
# │  └─ 2
# │     ├─ layer
# │     │  ├─ 1
# │     │  │  ├─ material ➡ "Steel, Stainless 316"
# │     │  │  ├─ midplane_thickness ➡ 0.0242053 [m]
# │     │  │  └─ name ➡ "hfs first wall"
# │     │  ├─ 2
# │     │  │  ├─ material ➡ "lithium-lead: Li6/7=29.927"
# │     │  │  ├─ midplane_thickness ➡ 0.33511 [m]
# │     │  │  └─ name ➡ "hfs blanket"
# │     │  └─ 3
# │     │     ├─ material ➡ "Tungsten"
# │     │     ├─ midplane_thickness ➡ 0.398324 [m]
# │     │     └─ name ➡ "hfs high temp shield"
# │     ├─ name ➡ "HFS blanket"
# │     └─ time_slice
# │        └─ 1
# │           ├─ neutron_shine_through ➡ 0.245222
# │           ├─ power_incident_neutrons ➡ 1.12316e+08 [W]
# │           ├─ power_incident_radiated ➡ 0 [W]
# │           ├─ power_thermal_extracted ➡ 1.34779e+08 [W]
# │           ├─ power_thermal_neutrons ➡ 1.34779e+08 [W]
# │           ├─ power_thermal_radiated ➡ 0 [W]
# │           └─ tritium_breeding_ratio ➡ 0.376051
# ├─ time ➡ [0] [s]
# └─ tritium_breeding_ratio ➡ [1.1]
